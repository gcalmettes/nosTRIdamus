# %%
import json
import requests
import pandas as pd
import numpy as np
from config import Cfg

# # opencage API key (https://opencagedata.com/)
# with open("./../config/opencage-api-key.txt", "r") as f:
#     apiKey = f.readline().strip()

apiKey = Cfg.opencage_api_key

# %%
def getUserLocation(address):
    requestString = f"https://api.opencagedata.com/geocode/v1/json?q={address}&key={apiKey}"
    r = requests.get(requestString)
    results = r.json()['results']
    return results

# %%
testAddress = "506 Canyon Drive, Oceanside"
getUserLocation(testAddress)
# Out:
# [{'annotations': {'DMS': {'lat': "33° 12' 6.28200'' N",
#     'lng': "117° 21' 18.95040'' W"},
#    'FIPS': {'county': '06073', 'state': '06'},
#    'MGRS': '11SMS6688873708',
#    'Maidenhead': 'DM13he78ik',
#    'Mercator': {'x': -13063928.23, 'y': 3898716.53},
#    'OSM': {'edit_url': 'https://www.openstreetmap.org/edit?node=595971049#map=17/33.20175/-117.35526',
#     'url': 'https://www.openstreetmap.org/?mlat=33.20175&mlon=-117.35526#map=17/33.20175/-117.35526'},
#    'UN_M49': {'regions': {'AMERICAS': '019',
#      'NORTHERN_AMERICA': '021',
#      'US': '840',
#      'WORLD': '001'},
#     'statistical_groupings': ['MEDC']},
#    'callingcode': 1,
#    'currency': {'alternate_symbols': ['US$'],
#     'decimal_mark': '.',
#     'disambiguate_symbol': 'US$',
#     'html_entity': '$',
#     'iso_code': 'USD',
#     'iso_numeric': '840',
#     'name': 'United States Dollar',
#     'smallest_denomination': 1,
#     'subunit': 'Cent',
#     'subunit_to_unit': 100,
#     'symbol': '$',
#     'symbol_first': 1,
#     'thousands_separator': ','},
#    'flag': '🇺🇸',
#    'geohash': '9muscs0w0jug835gdxgb',
#    'qibla': 24.96,
#    'roadinfo': {'drive_on': 'right',
#     'road': 'Canyon Drive',
#     'speed_in': 'mph'},
#    'sun': {'rise': {'apparent': 1560775140,
#      'astronomical': 1560768960,
#      'civil': 1560773400,
#      'nautical': 1560771300},
#     'set': {'apparent': 1560740400,
#      'astronomical': 1560746580,
#      'civil': 1560742140,
#      'nautical': 1560744240}},
#    'timezone': {'name': 'America/Los_Angeles',
#     'now_in_dst': 1,
#     'offset_sec': -25200,
#     'offset_string': '-0700',
#     'short_name': 'PDT'},
#    'what3words': {'words': 'thumps.circle.luck'}},
#   'bounds': {'northeast': {'lat': 33.201795, 'lng': -117.355214},
#    'southwest': {'lat': 33.201695, 'lng': -117.355314}},
#   'components': {'ISO_3166-1_alpha-2': 'US',
#    'ISO_3166-1_alpha-3': 'USA',
#    '_type': 'building',
#    'city': 'Oceanside',
#    'continent': 'North America',
#    'country': 'USA',
#    'country_code': 'us',
#    'county': 'San Diego County',
#    'house_number': '506',
#    'postcode': '92054',
#    'road': 'Canyon Drive',
#    'state': 'California',
#    'state_code': 'CA'},
#   'confidence': 10,
#   'formatted': '506 Canyon Drive, Oceanside, CA 92054, United States of America',
#   'geometry': {'lat': 33.201745, 'lng': -117.355264}},
#  {'annotations': {'DMS': {'lat': "33° 11' 45.13200'' N",
#     'lng': "117° 22' 46.12800'' W"},
#    'FIPS': {'county': '06073', 'state': '06'},
#    'MGRS': '11SMS6462873065',
#    'Maidenhead': 'DM13he47la',
#    'Mercator': {'x': -13066623.943, 'y': 3897938.627},
#    'OSM': {'url': 'https://www.openstreetmap.org/?mlat=33.19587&mlon=-117.37948#map=17/33.19587/-117.37948'},
#    'UN_M49': {'regions': {'AMERICAS': '019',
#      'NORTHERN_AMERICA': '021',
#      'US': '840',
#      'WORLD': '001'},
#     'statistical_groupings': ['MEDC']},
#    'callingcode': 1,
#    'currency': {'alternate_symbols': ['US$'],
#     'decimal_mark': '.',
#     'disambiguate_symbol': 'US$',
#     'html_entity': '$',
#     'iso_code': 'USD',
#     'iso_numeric': '840',
#     'name': 'United States Dollar',
#     'smallest_denomination': 1,
#     'subunit': 'Cent',
#     'subunit_to_unit': 100,
#     'symbol': '$',
#     'symbol_first': 1,
#     'thousands_separator': ','},
#    'flag': '🇺🇸',
#    'geohash': '9musbgnggysjb17mckd3',
#    'qibla': 24.94,
#    'roadinfo': {'drive_on': 'right', 'speed_in': 'mph'},
#    'sun': {'rise': {'apparent': 1560775140,
#      'astronomical': 1560768960,
#      'civil': 1560773400,
#      'nautical': 1560771300},
#     'set': {'apparent': 1560740400,
#      'astronomical': 1560746580,
#      'civil': 1560742140,
#      'nautical': 1560744240}},
#    'timezone': {'name': 'America/Los_Angeles',
#     'now_in_dst': 1,
#     'offset_sec': -25200,
#     'offset_string': '-0700',
#     'short_name': 'PDT'},
#    'what3words': {'words': 'vibrations.anchoring.list'}},
#   'bounds': {'northeast': {'lat': 33.300062, 'lng': -117.236845},
#    'southwest': {'lat': 33.152718, 'lng': -117.399785}},
#   'components': {'ISO_3166-1_alpha-2': 'US',
#    'ISO_3166-1_alpha-3': 'USA',
#    '_type': 'city',
#    'continent': 'North America',
#    'country': 'United States of America',
#    'country_code': 'us',
#    'county': 'San Diego County',
#    'state': 'California',
#    'state_code': 'CA',
#    'town': 'Oceanside'},
#   'confidence': 5,
#   'formatted': 'Oceanside, CA, United States of America',
#   'geometry': {'lat': 33.19587, 'lng': -117.37948}}]

# %%
# get all cities from races for which we have data

with open('./../data/races/races.jl', 'r') as f:
    races = [json.loads(line.strip()) for line in f.readlines()]
    
locations = set()
for race in races:
    if race["location"] != '---':
        locations.add(race["location"])
len(locations)
# Out:
# 176

# %%
# Get geo information from city/country using the OpenCage API

retrieve = False

if retrieve:
    # retrieve geographic data from city names
    citiesDict = {}

    # for cityName in locations:
    for cityName in locations:
        if cityName == "Jixian, Tianjin Province":
            toSearch = "Tianjin, China"
        else:
            toSearch = cityName
        requestString = f"https://api.opencagedata.com/geocode/v1/json?q={toSearch}&key={apiKey}"
        r = requests.get(requestString)
        results = r.json()['results']
        citiesDict[cityName] = results
    
    # save geo data
    with open('./../data/geo-data/cities-location-data.json', 'w') as f:
        f.write(json.dumps(citiesDict))
else:
    with open('./../data/geo-data/cities-location-data.json', 'r') as f:
        citiesDict = json.loads(f.read())

# %%
# cities may have multiple results, that's fine.
# but make sure there are no "no results"
for city in citiesDict:
    if len(citiesDict[city]) == 0:
        print(f"No result for {city}")

# %%
# regions of the world
regions = pd.read_csv("./../data/geo-data/country-regions.csv")

# create clean city data
cities_clean = {}
for city in citiesDict:
    city_info = citiesDict[city]
    # take result with the most confidence
    confidence_list = list(map(lambda x: x['confidence'], city_info))
    indexMaxConf = confidence_list.index(max(confidence_list))
    city_info = city_info[indexMaxConf]
    cities_clean[city] = city_info["geometry"]
    cities_clean[city]['continent'] = city_info['components']['continent']
    cities_clean[city]['country'] = city_info['components']['country']
    cities_clean[city]['country_code'] = city_info['components']['country_code']
    cities_clean[city]['state'] = city_info['components'].get('state')
    cities_clean[city]['state_code'] = city_info['components'].get('state_code')
    cities_clean[city]['county'] = city_info['components'].get('county')
    cities_clean[city]['formatted'] = city_info['formatted']
#     # update lat/lon
#     lat,lon = city_info["geometry"].values()
#     races.loc[races.city==city, "lat"] = lat
#     races.loc[races.city==city, "lng"] = lon
#     # update region
#     countryInfo = [el for el in cityDict[city]["address_components"] if el['types'] == ['country', 'political']]
#     races.loc[races.city==city, "region"] = " ".join(regions[regions.Country==countryInfo[0]["long_name"]].Region.to_string().split()[1:])
    
# # save
# races.to_csv("races-latlon-region.csv", index=False)

# %%
cities_clean
# Out:
# {'Monterrey, Mexico': {'lat': 25.6397836,
#   'lng': -100.2931016,
#   'continent': 'North America'},
#  'Panama City': {'lat': 8.9714493,
#   'lng': -79.5341802,
#   'continent': 'South America'},
#  'Bariloche, Argentina': {'lat': -41.1334672,
#   'lng': -71.3099936,
#   'continent': 'South America'},
#  'Putrajaya, Malaysia': {'lat': 2.9069676,
#   'lng': 101.6750533,
#   'continent': 'Asia'},
#  'Haines City, Florida': {'lat': 28.1090591,
#   'lng': -81.6271184,
#   'continent': 'North America'},
#  'Muscat, Al Qurm': {'lat': 23.6096426,
#   'lng': 58.4542247,
#   'continent': 'Asia'},
#  'Pucon, Chile': {'lat': -39.2731173,
#   'lng': -71.9777605,
#   'continent': 'South America'},
#  'Florianopolis, Brazil': {'lat': -27.5973002,
#   'lng': -48.5496098,
#   'continent': 'South America'},
#  'Traverse City, Michigan': {'lat': 44.7606441,
#   'lng': -85.6165301,
#   'continent': 'North America'},
#  'Atlantic City, New Jersey': {'lat': 39.3642852,
#   'lng': -74.4229351,
#   'continent': 'North America'},
#  'Benton Harbor, Michigan': {'lat': 42.1167065,
#   'lng': -86.4541894,
#   'continent': 'North America'},
#  'Staffordshire, England': {'lat': 52.8246942,
#   'lng': -2.0074547,
#   'continent': 'Europe'},
#  'Lima, Peru': {'lat': -12.0621065,
#   'lng': -77.0365256,
#   'continent': 'South America'},
#  'Gilford, New Hampshire, USA': {'lat': 43.54805,
#   'lng': -71.407013,
#   'continent': 'North America'},
#  'Racine, Wisconsin': {'lat': 42.7260523,
#   'lng': -87.7825242,
#   'continent': 'North America'},
#  'Ballarat, Victoria': {'lat': -37.5622632,
#   'lng': 143.8607215,
#   'continent': 'Oceania'},
#  'Mont-Tremblant, Québec, Canada': {'lat': 46.11588,
#   'lng': -74.5891426,
#   'continent': 'North America'},
#  'Wilmington, North Carolina': {'lat': 34.2257282,
#   'lng': -77.9447107,
#   'continent': 'North America'},
#  'Jönköping, Sweden': {'lat': 57.7814709,
#   'lng': 14.1627579,
#   'continent': 'Europe'},
#  'Alcudia, Mallorca, Spain': {'lat': 39.5643596,
#   'lng': 3.1154708,
#   'continent': 'Europe'},
#  'Calella, Spain': {'lat': 41.6132925,
#   'lng': 2.6576102,
#   'continent': 'Europe'},
#  'Austria': {'lat': 47.2000338, 'lng': 13.199959, 'continent': 'Europe'},
#  'Los Cabos, Mexico': {'lat': 23.271848,
#   'lng': -109.6897684,
#   'continent': 'North America'},
#  'Muskoka, Ontario, Canada': {'lat': 45.1307013,
#   'lng': -79.3839611,
#   'continent': 'North America'},
#  'Astana, Kazakhstan': {'lat': 51.1282205,
#   'lng': 71.4306682,
#   'continent': 'Asia'},
#  'Auvergne, France': {'lat': 45.7100132,
#   'lng': 3.1531803,
#   'continent': 'Europe'},
#  "Coeur d'Alene, Idaho": {'lat': 47.6742994,
#   'lng': -116.7811531,
#   'continent': 'North America'},
#  'Buenos Aires, Argentina': {'lat': -34.6075682,
#   'lng': -58.4370894,
#   'continent': 'South America'},
#  'Boise, Idaho': {'lat': 43.61656,
#   'lng': -116.200835,
#   'continent': 'North America'},
#  'Miami, Florida': {'lat': 25.7742658,
#   'lng': -80.1936589,
#   'continent': 'North America'},
#  'Nice, France': {'lat': 43.7009358, 'lng': 7.2683912, 'continent': 'Europe'},
#  'Brazil': {'lat': -10.3333333, 'lng': -53.2, 'continent': 'South America'},
#  'Old Orchard Beach, Maine': {'lat': 43.517684,
#   'lng': -70.377731,
#   'continent': 'North America'},
#  'Lubbock, Texas': {'lat': 33.5778631,
#   'lng': -101.8551665,
#   'continent': 'North America'},
#  'St.Pölten, Lower Austria, Austria': {'lat': 48.2043985,
#   'lng': 15.6229118,
#   'continent': 'Europe'},
#  'Canarias, Spain': {'lat': 28.2935785,
#   'lng': -16.6214471,
#   'continent': 'Europe'},
#  'Incheon, Korea': {'lat': 37.4734048,
#   'lng': 126.6165903,
#   'continent': 'Asia'},
#  'Hokkaido, Japan': {'lat': 43.4603175,
#   'lng': 143.3307158,
#   'continent': 'Asia'},
#  'Waco, Texas': {'lat': 31.549333,
#   'lng': -97.1466695,
#   'continent': 'North America'},
#  'Newfound Lake, NH': {'lat': 43.6595071,
#   'lng': -71.7768731,
#   'continent': 'North America'},
#  'Itaipu Hydroelectric, Foz do Iguaçu, Brasil ': {'lat': -25.54778,
#   'lng': -54.58806,
#   'continent': 'South America'},
#  'Singapore': {'lat': 1.2904753, 'lng': 103.8520359, 'continent': 'Asia'},
#  'Syracuse, New York': {'lat': 43.0481221,
#   'lng': -76.1474244,
#   'continent': 'North America'},
#  'Yeppoon, Queensland, Australia': {'lat': -23.1348035,
#   'lng': 150.7436625,
#   'continent': 'Oceania'},
#  'Branson, Missouri': {'lat': 36.6411357,
#   'lng': -93.2175285,
#   'continent': 'North America'},
#  'Chungju, Korea': {'lat': 36.9907334,
#   'lng': 127.9259891,
#   'continent': 'Asia'},
#  'Dublin, Ireland': {'lat': 53.3497645,
#   'lng': -6.2602732,
#   'continent': 'Europe'},
#  'Playa del Coco, Costa Rica': {'lat': 10.5579948,
#   'lng': -85.692262,
#   'continent': 'North America'},
#  'Los Cabos, Baja California, Mexico': {'lat': 31.7006406,
#   'lng': -116.5607536,
#   'continent': 'North America'},
#  'Stroudsburg, Pennsylvania': {'lat': 40.9864261,
#   'lng': -75.1946649,
#   'continent': 'North America'},
#  'Shanghai, China': {'lat': 31.2252985,
#   'lng': 121.4890497,
#   'continent': 'Asia'},
#  'Istria, Croatia': {'lat': 45.1893723,
#   'lng': 13.9181961,
#   'continent': 'Europe'},
#  'Copenhagen, Denmark': {'lat': 55.6867243,
#   'lng': 12.5700724,
#   'continent': 'Europe'},
#  'Liuzhou, China': {'lat': 24.3285821, 'lng': 109.409259, 'continent': 'Asia'},
#  'Windsor, California': {'lat': 38.5471327,
#   'lng': -122.8163802,
#   'continent': 'North America'},
#  'Kalmar, Sweden': {'lat': 56.6628826,
#   'lng': 16.3662382,
#   'continent': 'Europe'},
#  'Xiamen, China': {'lat': 24.4586961, 'lng': 118.0745391, 'continent': 'Asia'},
#  'Iracema Beach': {'lat': -5.8106219,
#   'lng': -38.3028294,
#   'continent': 'South America'},
#  'Mont-Tremblant, Quebec, Canada': {'lat': 46.11588,
#   'lng': -74.5891426,
#   'continent': 'North America'},
#  'Campeche, Mexico': {'lat': 19.3292056,
#   'lng': -89.9439148,
#   'continent': 'North America'},
#  'Aarhus, Denmark': {'lat': 56.1496278,
#   'lng': 10.2134046,
#   'continent': 'Europe'},
#  'Hamburg, Germany': {'lat': 53.550341,
#   'lng': 10.000654,
#   'continent': 'Europe'},
#  'Western Sydney, New South Wales': {'lat': -33.9175545,
#   'lng': 151.2291515,
#   'continent': 'Oceania'},
#  'Victoria, BC, Canada': {'lat': 48.4283182,
#   'lng': -123.3649533,
#   'continent': 'North America'},
#  'Zurich, Switzerland': {'lat': 47.3723941,
#   'lng': 8.5423328,
#   'continent': 'Europe'},
#  'Pescara, Italy': {'lat': 42.469613,
#   'lng': 14.2059269,
#   'continent': 'Europe'},
#  'Henderson, Nevada': {'lat': 36.0301134,
#   'lng': -114.9826194,
#   'continent': 'North America'},
#  'Budapest, Hungary': {'lat': 47.4983815,
#   'lng': 19.0404707,
#   'continent': 'Europe'},
#  'Saipan, Northern Mariana Islands': {'lat': 15.1909828,
#   'lng': 145.7468535,
#   'continent': 'Oceania'},
#  'Santa Rosa, California': {'lat': 38.4404675,
#   'lng': -122.7144314,
#   'continent': 'North America'},
#  'Nelson Mandela Bay, South Africa': {'lat': -26.5234633,
#   'lng': 29.1962243,
#   'continent': 'Africa'},
#  'Lawrence, Kansas': {'lat': 38.9719384,
#   'lng': -95.2359496,
#   'continent': 'North America'},
#  'New Orleans, Louisiana': {'lat': 29.9499323,
#   'lng': -90.0701156,
#   'continent': 'North America'},
#  'Frankfurt, Germany': {'lat': 50.1106444,
#   'lng': 8.6820917,
#   'continent': 'Europe'},
#  'Manta, Ecuador': {'lat': -1.0321654,
#   'lng': -80.8222833,
#   'continent': 'South America'},
#  'Greece': {'lat': 38.9953683, 'lng': 21.9877132, 'continent': 'Europe'},
#  'Williamsburg, Virginia': {'lat': 37.2789211,
#   'lng': -76.6944861,
#   'continent': 'North America'},
#  'Louisville, KY': {'lat': 38.2542376,
#   'lng': -85.759407,
#   'continent': 'North America'},
#  'Tempe, Arizona ': {'lat': 33.4255056,
#   'lng': -111.9400125,
#   'continent': 'North America'},
#  'Panama City Beach, Florida': {'lat': 30.1765914,
#   'lng': -85.8054879,
#   'continent': 'North America'},
#  'Auckland, New Zealand': {'lat': -36.8534665,
#   'lng': 174.7655514,
#   'continent': 'Oceania'},
#  'Fotaleza, Brazil': {'lat': -10.0,
#   'lng': -55.0,
#   'continent': 'South America'},
#  'Dun Laoghaire, Co. Dublin, Ireland': {'lat': 53.2922794,
#   'lng': -6.1360079,
#   'continent': 'Europe'},
#  'Region Moselle, Luxembourg': {'lat': 49.61167,
#   'lng': 6.13,
#   'continent': 'Europe'},
#  'Melbourne, Victoria': {'lat': -37.8142176,
#   'lng': 144.9631608,
#   'continent': 'Oceania'},
#  'Rapperswil-Jona, Switzerland': {'lat': 47.2298277,
#   'lng': 8.8596509,
#   'continent': 'Europe'},
#  'Subic Bay, Philippines': {'lat': 14.8203471,
#   'lng': 120.2815287,
#   'continent': 'Asia'},
#  'Princeton, New Jersey, USA': {'lat': 40.3492744,
#   'lng': -74.6592958,
#   'continent': 'North America'},
#  'Cozumel, Mexico': {'lat': 20.4317585,
#   'lng': -86.9202746,
#   'continent': 'North America'},
#  'Delaware, Ohio': {'lat': 40.2986724,
#   'lng': -83.067965,
#   'continent': 'North America'},
#  'Centrair Tokoname, Japan': {'lat': 34.8587197,
#   'lng': 136.8113634,
#   'continent': 'Asia'},
#  'Bolton, England': {'lat': 53.577694,
#   'lng': -2.4288874,
#   'continent': 'Europe'},
#  'Goseong, Korea': {'lat': 34.9732784, 'lng': 128.322233, 'continent': 'Asia'},
#  'September 7 & 8': {'lat': -33.6709374,
#   'lng': 18.9991753,
#   'continent': 'Africa'},
#  'Austin, Texas': {'lat': 30.2711286,
#   'lng': -97.7436995,
#   'continent': 'North America'},
#  'Pembrokeshire, Wales': {'lat': 51.8339209,
#   'lng': -4.916667,
#   'continent': 'Europe'},
#  'KwaZulu-Natal, South Africa': {'lat': -28.503833,
#   'lng': 30.8875009,
#   'continent': 'Africa'},
#  'Palmas, Brazil': {'lat': -10.1835604,
#   'lng': -48.3337793,
#   'continent': 'South America'},
#  'St. Croix, U.S. Virgin Islands': {'lat': 17.7289564,
#   'lng': -64.759016,
#   'continent': 'North America'},
#  'Port Macquarie, Australia': {'lat': -31.4299499,
#   'lng': 152.9103525,
#   'continent': 'Oceania'},
#  'Aix en Provence, France': {'lat': 43.5298424,
#   'lng': 5.4474738,
#   'continent': 'Europe'},
#  'Slovenia': {'lat': 45.8133113, 'lng': 14.4808369, 'continent': 'Europe'},
#  'Lahti, Finland': {'lat': 60.9838761,
#   'lng': 25.6561814,
#   'continent': 'Europe'},
#  'Wimbleball, England': {'lat': 51.0656227,
#   'lng': -3.4673337,
#   'continent': 'Europe'},
#  'Penghu, Taiwan': {'lat': 23.569694, 'lng': 119.5664543, 'continent': 'Asia'},
#  'Danang, Vietnam': {'lat': 16.0425792,
#   'lng': 108.1971587,
#   'continent': 'Asia'},
#  'Boulder, Colorado': {'lat': 40.0149856,
#   'lng': -105.2705456,
#   'continent': 'North America'},
#  'Lanzarote, Canary Islands, Spain': {'lat': 29.0397081,
#   'lng': -13.6362916,
#   'continent': 'Europe'},
#  'Tempe, AZ': {'lat': 33.4255056,
#   'lng': -111.9400125,
#   'continent': 'North America'},
#  'Geelong, Victoria': {'lat': -38.1492813,
#   'lng': 144.3598269,
#   'continent': 'Oceania'},
#  'Haugesund, Norway': {'lat': 59.4154805,
#   'lng': 5.2636464,
#   'continent': 'Europe'},
#  'Cascais, Portugal': {'lat': 38.7224002,
#   'lng': -9.3969092,
#   'continent': 'Europe'},
#  'Klagenfurt, Austria': {'lat': 46.6228162,
#   'lng': 14.3079604,
#   'continent': 'Europe'},
#  'Lake Stevens, Washington': {'lat': 48.0014651,
#   'lng': -122.0821094,
#   'continent': 'North America'},
#  'Cebu, Philippines': {'lat': 10.474516,
#   'lng': 123.864283,
#   'continent': 'Asia'},
#  'Spain': {'lat': 39.3262345, 'lng': -4.8380649, 'continent': 'Europe'},
#  'Edinburgh, Scotland': {'lat': 55.953346,
#   'lng': -3.1883739,
#   'continent': 'Europe'},
#  'Langkawi, Malaysia': {'lat': 6.3700386,
#   'lng': 99.7928634,
#   'continent': 'Asia'},
#  'Maceió, Alagoas Brazil': {'lat': -9.6476843,
#   'lng': -35.7339264,
#   'continent': 'South America'},
#  'Providence, Rhode Island': {'lat': 41.8239891,
#   'lng': -71.4128343,
#   'continent': 'North America'},
#  'New York City, NY': {'lat': 40.7127281,
#   'lng': -74.0060152,
#   'continent': 'North America'},
#  'Lake Tahoe, California': {'lat': 39.0885405,
#   'lng': -120.0503528,
#   'continent': 'North America'},
#  'Imperial Beach, California': {'lat': 32.5839444,
#   'lng': -117.1130849,
#   'continent': 'North America'},
#  'Dorset, UK': {'lat': 50.7968346, 'lng': -2.4146294, 'continent': 'Europe'},
#  'Bintan, Indonesia': {'lat': -6.3499382,
#   'lng': 106.7814388,
#   'continent': 'Asia'},
#  'Hefei, China': {'lat': 31.8228094, 'lng': 117.2218033, 'continent': 'Asia'},
#  'Gdynia, Poland': {'lat': 54.5164982,
#   'lng': 18.5402738,
#   'continent': 'Europe'},
#  'Mandurah, Western Australia': {'lat': -32.5302495,
#   'lng': 115.7208782,
#   'continent': 'Oceania'},
#  'Galway, Ireland': {'lat': 53.2744122,
#   'lng': -9.0490632,
#   'continent': 'Europe'},
#  'Phuket, Thailand': {'lat': 7.9366015,
#   'lng': 98.3529292,
#   'continent': 'Asia'},
#  'Taupo, New Zealand': {'lat': -38.6866197,
#   'lng': 176.0694773,
#   'continent': 'Oceania'},
#  'Jixian, Tianjin Province': {'lat': 39.1235635,
#   'lng': 117.1980785,
#   'continent': 'Asia'},
#  'Chattanooga, Tennessee': {'lat': 35.0456297,
#   'lng': -85.3096801,
#   'continent': 'North America'},
#  'San Juan, Puerto Rico': {'lat': 18.465299,
#   'lng': -66.116666,
#   'continent': 'North America'},
#  'Santa Cruz, California': {'lat': 36.9749416,
#   'lng': -122.0285259,
#   'continent': 'North America'},
#  'Busselton, Western Australia': {'lat': -33.644499,
#   'lng': 115.3488754,
#   'continent': 'Oceania'},
#  'Busan, Korea': {'lat': 35.1799528, 'lng': 129.0752365, 'continent': 'Asia'},
#  'Laguna, Phuket, Thailand': {'lat': 8.0159648,
#   'lng': 98.3011174,
#   'continent': 'Asia'},
#  'Coquimbo, Chile': {'lat': -29.9531928,
#   'lng': -71.3379884,
#   'continent': 'South America'},
#  'Galveston, Texas': {'lat': 29.299328,
#   'lng': -94.7945882,
#   'continent': 'North America'},
#  'Limburg, The Netherlands': {'lat': 51.2008195,
#   'lng': 5.9041916,
#   'continent': 'Europe'},
#  'Otepää': {'lat': 58.0584907, 'lng': 26.4960599, 'continent': 'Europe'},
#  'Wiesbaden, Germany': {'lat': 50.0820384,
#   'lng': 8.2416556,
#   'continent': 'Europe'},
#  'Kailua-Kona, Hawai`i': {'lat': 19.641941,
#   'lng': -155.996933,
#   'continent': 'North America'},
#  'Davao, Philippines': {'lat': 7.0645241,
#   'lng': 125.6084143,
#   'continent': 'Asia'},
#  'Regensburg, Germany': {'lat': 49.0195333,
#   'lng': 12.0974869,
#   'continent': 'Europe'},
#  'Muncie, Indiana': {'lat': 40.1936892,
#   'lng': -85.3865271,
#   'continent': 'North America'},
#  'Buffalo City, East London': {'lat': -33.0191604,
#   'lng': 27.8998573,
#   'continent': 'Africa'},
#  'Cambridge, Maryland': {'lat': 38.5714624,
#   'lng': -76.0763177,
#   'continent': 'North America'},
#  'Belek, Turkey': {'lat': 36.8633459, 'lng': 31.0578184, 'continent': 'Asia'},
#  'Manama, Bahrain': {'lat': 26.2235041,
#   'lng': 50.5822436,
#   'continent': 'Asia'},
#  'Taitung, Taiwan': {'lat': 22.7934597,
#   'lng': 121.1224316,
#   'continent': 'Asia'},
#  'St. George, Utah': {'lat': 37.104153,
#   'lng': -113.5841313,
#   'continent': 'North America'},
#  'Monaco': {'lat': 43.7384402, 'lng': 7.4242474, 'continent': 'Europe'},
#  'Dubai, United Arab Emirates': {'lat': 25.0750095,
#   'lng': 55.1887609,
#   'continent': 'Asia'},
#  'Indian Wells/La Quinta, California, USA': {'lat': 33.7217965,
#   'lng': -116.3383034,
#   'continent': 'North America'},
#  'Ruegen, Germany': {'lat': 54.4529452,
#   'lng': 13.3882303,
#   'continent': 'Europe'},
#  'Raleigh, North Carolina': {'lat': 35.7803977,
#   'lng': -78.6390989,
#   'continent': 'North America'},
#  'Madison, Wisconsin': {'lat': 43.074761,
#   'lng': -89.3837613,
#   'continent': 'North America'},
#  'Mooloolaba, Queensland, Australia': {'lat': -26.6791955,
#   'lng': 153.1137635,
#   'continent': 'Oceania'},
#  'Colombo, Sri Lanka': {'lat': 6.9349969,
#   'lng': 79.8538463,
#   'continent': 'Asia'},
#  'Qujing, China': {'lat': 25.4902717, 'lng': 103.79654, 'continent': 'Asia'},
#  'Augusta, Georgia': {'lat': 33.4709714,
#   'lng': -81.9748429,
#   'continent': 'North America'},
#  'Kohala Coast, Hawai`i': {'lat': 18.16667,
#   'lng': -7.08333,
#   'continent': 'Africa'},
#  'Whistler, BC, Canada': {'lat': 50.1171903,
#   'lng': -122.9543022,
#   'continent': 'North America'},
#  'The Woodlands, Texas': {'lat': 30.1734194,
#   'lng': -95.504686,
#   'continent': 'North America'},
#  'Calgary, AB, Canada': {'lat': 51.0253267,
#   'lng': -114.0498685,
#   'continent': 'North America'},
#  'Elsinore, Denmark': {'lat': 56.0345277,
#   'lng': 12.6136135,
#   'continent': 'Europe'},
#  'Punta del Este, Uruguay': {'lat': -34.9632342,
#   'lng': -54.9439981,
#   'continent': 'South America'},
#  'Gurye, Korea': {'lat': 35.2017233, 'lng': 127.460168, 'continent': 'Asia'},
#  'Cartagena, Colombia': {'lat': 10.4195841,
#   'lng': -75.5271224,
#   'continent': 'South America'},
#  'Cairns, Queensland, Australia': {'lat': -16.9206657,
#   'lng': 145.7721854,
#   'continent': 'Oceania'},
#  'Cervia, Italy': {'lat': 44.2609836,
#   'lng': 12.3495462,
#   'continent': 'Europe'},
#  'Mar del Plata, Argentina': {'lat': -37.9977225,
#   'lng': -57.5482703,
#   'continent': 'South America'},
#  'Oceanside, California': {'lat': 33.1958696,
#   'lng': -117.3794834,
#   'continent': 'North America'},
#  'Lake Placid, NY': {'lat': 44.279621,
#   'lng': -73.979874,
#   'continent': 'North America'}}

# %%
regions
# Out:
#                                   Country               Region  Global South
# 0                                 Andorra               Europe  Global North
# 1                    United Arab Emirates          Arab States  Global South
# 2                             Afghanistan       Asia & Pacific  Global South
# 3                     Antigua and Barbuda  South/Latin America  Global South
# 4                                Anguilla  South/Latin America  Global South
# 5                                 Albania               Europe  Global North
# 6                                 Armenia                  CIS  Global South
# 7                    Netherlands Antilles  South/Latin America  Global South
# 8                                  Angola               Africa  Global South
# 9                              Antarctica       Asia & Pacific  Global South
# 10                              Argentina  South/Latin America  Global South
# 11                         American Samoa       Asia & Pacific  Global South
# 12                                Austria               Europe  Global North
# 13                              Australia       Asia & Pacific  Global North
# 14                                  Aruba  South/Latin America  Global South
# 15                             Azerbaijan                  CIS  Global South
# 16                 Bosnia and Herzegovina               Europe  Global North
# 17                               Barbados  South/Latin America  Global South
# 18                             Bangladesh       Asia & Pacific  Global South
# 19                                Belgium               Europe  Global North
# 20                           Burkina Faso               Africa  Global South
# 21                               Bulgaria               Europe  Global North
# 22                                Bahrain          Arab States  Global South
# 23                                Burundi               Africa  Global South
# 24                                  Benin               Africa  Global South
# 25                                Bermuda        North America  Global North
# 26                      Brunei Darussalam       Asia & Pacific  Global South
# 27                                Bolivia  South/Latin America  Global South
# 28                                 Brazil  South/Latin America  Global South
# 29                                Bahamas  South/Latin America  Global South
# ..                                    ...                  ...           ...
# 220                               Ukraine                  CIS  Global South
# 221                                Uganda               Africa  Global South
# 222  United States Minor Outlying Islands       Asia & Pacific  Global South
# 223                         United States        North America  Global North
# 224                               Uruguay  South/Latin America  Global South
# 225                            Uzbekistan                  CIS  Global South
# 226         Holy See (Vatican City State)               Europe  Global North
# 227      Saint Vincent and the Grenadines  South/Latin America  Global South
# 228                             Venezuela  South/Latin America  Global South
# 229               Virgin Islands, British  South/Latin America  Global South
# 230                  Virgin Islands, U.S.  South/Latin America  Global South
# 231                   U.S. Virgin Islands  South/Latin America  Global South
# 232                British Virgin Islands  South/Latin America  Global South
# 233                               Vietnam       Asia & Pacific  Global South
# 234                               Vanuatu       Asia & Pacific  Global South
# 235                     Wallis and Futuna       Asia & Pacific  Global South
# 236                                 Samoa       Asia & Pacific  Global South
# 237                                 Yemen          Arab States  Global South
# 238                               Mayotte               Africa  Global South
# 239                                Serbia               Europe  Global North
# 240                          South Africa               Africa  Global South
# 241                                Zambia               Africa  Global South
# 242                            Montenegro               Europe  Global North
# 243                              Zimbabwe               Africa  Global South
# 244                         Aland Islands               Europe  Global North
# 245                              Guernsey               Europe  Global North
# 246                           Isle of Man               Europe  Global North
# 247                                Jersey               Europe  Global North
# 248                      Saint Barthelemy  South/Latin America  Global South
# 249                          Saint Martin  South/Latin America  Global South
#
# [250 rows x 3 columns]
